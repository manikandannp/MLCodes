# %%
import re
import os
import sys
import pandas as pd
import numpy as np


os.getcwd()

wkdir = "C:/Users/ShatheepR/Desktop/Adobe Audience Manager Build & Standardization/"  ## put Input file in working directory and set the working directory
os.chdir(wkdir)
os.getcwd()


df_pred  = pd.read_csv("Sample Input File.csv") ## Name of the input file name


####  Do not change anything below this line    ###########


df_pred.columns = df_pred.columns.str.replace("[()/ ]", "_")
attribute_list_pred = list(df_pred.columns)
Pred_Cols_listToStr = ' '.join([str(elem) for elem in attribute_list_pred])

attribute_list_check = ['DUNS','Domestic_Ultimate_Employee_Size','Domestic_Ultimate_Revenue', 'Employees_Here', 'Employee_Count_Total',  'Minority_Owned_Indicator', 'Population_Code', 'Revenue__US_Dollars_', 'Year_Started', 'Manufacturing_Indicator','Major_Industry_Category' ]

no_of_vars = 11
matched_vars = 0
for attribute in attribute_list_check:
    p = re.compile('\\b'+attribute+'\\b')
    if p.search(Pred_Cols_listToStr):
        matched_vars = matched_vars + 1
    else:      
        print("-----------")
        print("Could not find input Variable:  " +  attribute.replace("_"," "))
        
if matched_vars < no_of_vars:
    print("-----------")
    print("None of the respondents had values for: "+ str(no_of_vars - matched_vars) + " var(s). Please check the input file for variable names") 
    print("-----------")
    sys.exit()




df_pred.loc[(df_pred["Domestic_Ultimate_Employee_Size"] >= 0) & (df_pred["Domestic_Ultimate_Employee_Size"] < 25), 'Domestic_Ultimate_Employee_Range'] = "Less than 25"
df_pred.loc[(df_pred["Domestic_Ultimate_Employee_Size"] >= 25) & (df_pred["Domestic_Ultimate_Employee_Size"] < 100), 'Domestic_Ultimate_Employee_Range'] = "25 to less than 100"
df_pred.loc[(df_pred["Domestic_Ultimate_Employee_Size"] >= 100) & (df_pred["Domestic_Ultimate_Employee_Size"] < 500), 'Domestic_Ultimate_Employee_Range'] = "100 to less than 500"
df_pred.loc[(df_pred["Domestic_Ultimate_Employee_Size"] >= 500) & (df_pred["Domestic_Ultimate_Employee_Size"] < 1000), 'Domestic_Ultimate_Employee_Range'] = "500 to less than 1,000"
df_pred.loc[(df_pred["Domestic_Ultimate_Employee_Size"] >= 1000) & (df_pred["Domestic_Ultimate_Employee_Size"] < 5000), 'Domestic_Ultimate_Employee_Range'] = "1,000 to less than 5,000"
df_pred.loc[(df_pred["Domestic_Ultimate_Employee_Size"] >= 5000) & (df_pred["Domestic_Ultimate_Employee_Size"] < 25000), 'Domestic_Ultimate_Employee_Range'] = "5,000 to less than 25,000"
df_pred.loc[(df_pred["Domestic_Ultimate_Employee_Size"] >= 25000) & (df_pred["Domestic_Ultimate_Employee_Size"] < 100000), 'Domestic_Ultimate_Employee_Range'] = "25,000 to less than 100,000"
df_pred.loc[(df_pred["Domestic_Ultimate_Employee_Size"] >= 100000) , 'Domestic_Ultimate_Employee_Range'] = "100,000 and above"


df_pred.loc[(df_pred["Domestic_Ultimate_Revenue"] >= 0) & (df_pred["Domestic_Ultimate_Revenue"] < 1000000), 'Domestic_Ultimate_Revenue_Range'] = "Less than $1 mil"
df_pred.loc[(df_pred["Domestic_Ultimate_Revenue"] >= 1000000) & (df_pred["Domestic_Ultimate_Revenue"] < 5000000), 'Domestic_Ultimate_Revenue_Range'] = "$1 mil to less than $5 mil"
df_pred.loc[(df_pred["Domestic_Ultimate_Revenue"] >= 5000000) & (df_pred["Domestic_Ultimate_Revenue"] < 10000000), 'Domestic_Ultimate_Revenue_Range'] = "$5 mil to less than $10 mil"
df_pred.loc[(df_pred["Domestic_Ultimate_Revenue"] >= 10000000) & (df_pred["Domestic_Ultimate_Revenue"] < 25000000), 'Domestic_Ultimate_Revenue_Range'] = "$10 mil to less than $25 mil"
df_pred.loc[(df_pred["Domestic_Ultimate_Revenue"] >= 25000000) & (df_pred["Domestic_Ultimate_Revenue"] < 50000000), 'Domestic_Ultimate_Revenue_Range'] = "$25 mil to less than $50 mil"
df_pred.loc[(df_pred["Domestic_Ultimate_Revenue"] >= 50000000) & (df_pred["Domestic_Ultimate_Revenue"] < 100000000), 'Domestic_Ultimate_Revenue_Range'] = "$50 mil to less than $100 mil"
df_pred.loc[(df_pred["Domestic_Ultimate_Revenue"] >= 100000000) & (df_pred["Domestic_Ultimate_Revenue"] < 250000000), 'Domestic_Ultimate_Revenue_Range'] = "$100 mil to less than $250 mil"
df_pred.loc[(df_pred["Domestic_Ultimate_Revenue"] >= 250000000) & (df_pred["Domestic_Ultimate_Revenue"] < 500000000), 'Domestic_Ultimate_Revenue_Range'] = "$250 mil to less than $500 mil"
df_pred.loc[(df_pred["Domestic_Ultimate_Revenue"] >= 500000000) & (df_pred["Domestic_Ultimate_Revenue"] < 1000000000), 'Domestic_Ultimate_Revenue_Range'] = "$500 mil to less than $1 bil"
df_pred.loc[(df_pred["Domestic_Ultimate_Revenue"] >= 1000000000) , 'Domestic_Ultimate_Revenue_Range'] = "$1 bil and above"


df_pred.loc[(df_pred["Employees_Here"] >= 0) & (df_pred["Employees_Here"] < 25), 'Employee_Count_Range'] = "Less than 25"
df_pred.loc[(df_pred["Employees_Here"] >= 25) & (df_pred["Employees_Here"] < 100), 'Employee_Count_Range'] = "25 to less than 100"
df_pred.loc[(df_pred["Employees_Here"] >= 100) & (df_pred["Employees_Here"] < 500), 'Employee_Count_Range'] = "100 to less than 500"
df_pred.loc[(df_pred["Employees_Here"] >= 500) & (df_pred["Employees_Here"] < 1000), 'Employee_Count_Range'] = "500 to less than 1,000"
df_pred.loc[(df_pred["Employees_Here"] >= 1000) & (df_pred["Employees_Here"] < 5000), 'Employee_Count_Range'] = "1,000 to less than 5,000"
df_pred.loc[(df_pred["Employees_Here"] >= 5000) & (df_pred["Employees_Here"] < 25000), 'Employee_Count_Range'] = "5,000 to less than 25,000"
df_pred.loc[(df_pred["Employees_Here"] >= 25000) & (df_pred["Employees_Here"] < 100000), 'Employee_Count_Range'] = "25,000 to less than 100,000"
df_pred.loc[(df_pred["Employees_Here"] >= 100000) , 'Employee_Count_Range'] = "100,000 and above"



df_pred.loc[(df_pred["Revenue__US_Dollars_"] >= 0) & (df_pred["Revenue__US_Dollars_"] < 1000000), 'Revenue_Range'] = "Less than $1 mil"
df_pred.loc[(df_pred["Revenue__US_Dollars_"] >= 1000000) & (df_pred["Revenue__US_Dollars_"] < 5000000), 'Revenue_Range'] = "$1 mil to less than $5 mil"
df_pred.loc[(df_pred["Revenue__US_Dollars_"] >= 5000000) & (df_pred["Revenue__US_Dollars_"] < 10000000), 'Revenue_Range'] = "$5 mil to less than $10 mil"
df_pred.loc[(df_pred["Revenue__US_Dollars_"] >= 10000000) & (df_pred["Revenue__US_Dollars_"] < 25000000), 'Revenue_Range'] = "$10 mil to less than $25 mil"
df_pred.loc[(df_pred["Revenue__US_Dollars_"] >= 25000000) & (df_pred["Revenue__US_Dollars_"] < 50000000), 'Revenue_Range'] = "$25 mil to less than $50 mil"
df_pred.loc[(df_pred["Revenue__US_Dollars_"] >= 50000000) & (df_pred["Revenue__US_Dollars_"] < 100000000), 'Revenue_Range'] = "$50 mil to less than $100 mil"
df_pred.loc[(df_pred["Revenue__US_Dollars_"] >= 100000000) & (df_pred["Revenue__US_Dollars_"] < 250000000), 'Revenue_Range'] = "$100 mil to less than $250 mil"
df_pred.loc[(df_pred["Revenue__US_Dollars_"] >= 250000000) & (df_pred["Revenue__US_Dollars_"] < 500000000), 'Revenue_Range'] = "$250 mil to less than $500 mil"
df_pred.loc[(df_pred["Revenue__US_Dollars_"] >= 500000000) & (df_pred["Revenue__US_Dollars_"] < 1000000000), 'Revenue_Range'] = "$500 mil to less than $1 bil"
df_pred.loc[(df_pred["Revenue__US_Dollars_"] >= 1000000000) , 'Revenue_Range'] = "$1 bil and above"



df_pred.loc[df_pred["Domestic_Ultimate_Employee_Range"] == "Less than 25", 'Domestic_Ult_Emp_Range_num'] =1
df_pred.loc[df_pred["Domestic_Ultimate_Employee_Range"] == "25 to less than 100", 'Domestic_Ult_Emp_Range_num'] =2
df_pred.loc[df_pred["Domestic_Ultimate_Employee_Range"] == "100 to less than 500", 'Domestic_Ult_Emp_Range_num'] =3
df_pred.loc[df_pred["Domestic_Ultimate_Employee_Range"] == "500 to less than 1,000", 'Domestic_Ult_Emp_Range_num'] =4
df_pred.loc[df_pred["Domestic_Ultimate_Employee_Range"] == "1,000 to less than 5,000", 'Domestic_Ult_Emp_Range_num'] =5
df_pred.loc[df_pred["Domestic_Ultimate_Employee_Range"] == "5,000 to less than 25,000", 'Domestic_Ult_Emp_Range_num'] =6
df_pred.loc[df_pred["Domestic_Ultimate_Employee_Range"] == "25,000 to less than 100,000", 'Domestic_Ult_Emp_Range_num'] =7
df_pred.loc[df_pred["Domestic_Ultimate_Employee_Range"] == "100,000 and above", 'Domestic_Ult_Emp_Range_num'] =8

df_pred.loc[df_pred["Domestic_Ultimate_Revenue_Range"] == "Less than $1 mil", 'Domestic_Ult_Revenue_Range_num'] =1
df_pred.loc[df_pred["Domestic_Ultimate_Revenue_Range"] == "$1 mil to less than $5 mil", 'Domestic_Ult_Revenue_Range_num'] =2
df_pred.loc[df_pred["Domestic_Ultimate_Revenue_Range"] == "$5 mil to less than $10 mil", 'Domestic_Ult_Revenue_Range_num'] =3
df_pred.loc[df_pred["Domestic_Ultimate_Revenue_Range"] == "$10 mil to less than $25 mil", 'Domestic_Ult_Revenue_Range_num'] =4
df_pred.loc[df_pred["Domestic_Ultimate_Revenue_Range"] == "$25 mil to less than $50 mil", 'Domestic_Ult_Revenue_Range_num'] =5
df_pred.loc[df_pred["Domestic_Ultimate_Revenue_Range"] == "$50 mil to less than $100 mil", 'Domestic_Ult_Revenue_Range_num'] =6
df_pred.loc[df_pred["Domestic_Ultimate_Revenue_Range"] == "$100 mil to less than $250 mil", 'Domestic_Ult_Revenue_Range_num'] =7
df_pred.loc[df_pred["Domestic_Ultimate_Revenue_Range"] == "$250 mil to less than $500 mil", 'Domestic_Ult_Revenue_Range_num'] =8
df_pred.loc[df_pred["Domestic_Ultimate_Revenue_Range"] == "$500 mil to less than $1 bil", 'Domestic_Ult_Revenue_Range_num'] =9
df_pred.loc[df_pred["Domestic_Ultimate_Revenue_Range"] == "$1 bil and above", 'Domestic_Ult_Revenue_Range_num'] =10


df_pred.loc[df_pred["Employee_Count_Range"] == "Less than 25", 'Employee_Count_Range_num'] =1
df_pred.loc[df_pred["Employee_Count_Range"] == "25 to less than 100", 'Employee_Count_Range_num'] =2
df_pred.loc[df_pred["Employee_Count_Range"] == "100 to less than 500", 'Employee_Count_Range_num'] =3
df_pred.loc[df_pred["Employee_Count_Range"] == "500 to less than 1,000", 'Employee_Count_Range_num'] =4
df_pred.loc[df_pred["Employee_Count_Range"] == "1,000 to less than 5,000", 'Employee_Count_Range_num'] =5
df_pred.loc[df_pred["Employee_Count_Range"] == "5,000 to less than 25,000", 'Employee_Count_Range_num'] =6
df_pred.loc[df_pred["Employee_Count_Range"] == "25,000 to less than 100,000", 'Employee_Count_Range_num'] =7

df_pred.loc[(df_pred["Employee_Count_Total"] >= 0) & (df_pred["Employee_Count_Total"] <= 20), 'Employee_Count_Total_buckets2'] =1
df_pred.loc[(df_pred["Employee_Count_Total"] > 20) & (df_pred["Employee_Count_Total"] <= 1000), 'Employee_Count_Total_buckets2'] =2
df_pred.loc[(df_pred["Employee_Count_Total"] > 1000) , 'Employee_Count_Total_buckets2'] =3


df_pred.loc[df_pred["Minority_Owned_Indicator"] == "N", 'Minority_Owned_Indicator_num'] =0
df_pred.loc[df_pred["Minority_Owned_Indicator"] == "Y", 'Minority_Owned_Indicator_num'] =1

df_pred.loc[df_pred["Population_Code"] == 0, 'Population_Code_recoded'] =1
df_pred.loc[df_pred["Population_Code"] == 4, 'Population_Code_recoded'] =2
df_pred.loc[df_pred["Population_Code"] == 5, 'Population_Code_recoded'] =3
df_pred.loc[df_pred["Population_Code"] == 6, 'Population_Code_recoded'] =4
df_pred.loc[df_pred["Population_Code"] == 7, 'Population_Code_recoded'] =5
df_pred.loc[df_pred["Population_Code"] == 8, 'Population_Code_recoded'] =6
df_pred.loc[df_pred["Population_Code"] == 9, 'Population_Code_recoded'] =7

df_pred.loc[df_pred["Revenue_Range"] == "Less than $1 mil", 'Revenue_Range_buckets'] =1
df_pred.loc[df_pred["Revenue_Range"] == "$1 mil to less than $5 mil", 'Revenue_Range_buckets'] =1
df_pred.loc[df_pred["Revenue_Range"] == "$5 mil to less than $10 mil", 'Revenue_Range_buckets'] =2
df_pred.loc[df_pred["Revenue_Range"] == "$10 mil to less than $25 mil", 'Revenue_Range_buckets'] =2
df_pred.loc[df_pred["Revenue_Range"] == "$25 mil to less than $50 mil", 'Revenue_Range_buckets'] =2
df_pred.loc[df_pred["Revenue_Range"] == "$50 mil to less than $100 mil", 'Revenue_Range_buckets'] =2
df_pred.loc[df_pred["Revenue_Range"] == "$100 mil to less than $250 mil", 'Revenue_Range_buckets'] =2
df_pred.loc[df_pred["Revenue_Range"] == "$250 mil to less than $500 mil", 'Revenue_Range_buckets'] =2
df_pred.loc[df_pred["Revenue_Range"] == "$500 mil to less than $1 bil", 'Revenue_Range_buckets'] =2
df_pred.loc[df_pred["Revenue_Range"] == "$1 bil and above", 'Revenue_Range_buckets'] =3



df_pred["Revenue_per_emp"] = df_pred['Revenue__US_Dollars_']/df_pred['Employee_Count_Total']

df_pred.loc[(df_pred["Revenue_per_emp"] > 0) & (df_pred["Revenue_per_emp"] <= 70000), 'Revenue_per_emp_LMH'] =1
df_pred.loc[(df_pred["Revenue_per_emp"] > 70000) & (df_pred["Revenue_per_emp"] <= 270000), 'Revenue_per_emp_LMH'] =2
df_pred.loc[df_pred["Revenue_per_emp"] > 270000, 'Revenue_per_emp_LMH'] =3


df_pred['comp_age'] = 2019 - df_pred['Year_Started']

df_pred.loc[(df_pred["comp_age"] >= 0) & (df_pred["comp_age"] <= 3), 'company_age_group'] =1
df_pred.loc[(df_pred["comp_age"] > 3) & (df_pred["comp_age"] <= 10), 'company_age_group'] =2
df_pred.loc[(df_pred["comp_age"] > 10) & (df_pred["comp_age"] <= 25), 'company_age_group'] =3
df_pred.loc[(df_pred["comp_age"] > 25) & (df_pred["comp_age"] <= 50), 'company_age_group'] =4
df_pred.loc[df_pred["comp_age"] > 50, 'company_age_group'] =5

df_pred.loc[df_pred['Year_Started'] == 0, 'company_age_group'] = 999


df_pred.loc[(df_pred["Employee_Count_Total"] >= 0) & (df_pred["Employee_Count_Total"] < 1000), 'Employee_Count_Total_buckets'] =1
df_pred.loc[(df_pred["Employee_Count_Total"] >= 1000) & (df_pred["Employee_Count_Total"] < 5000), 'Employee_Count_Total_buckets'] =2
df_pred.loc[df_pred["Employee_Count_Total"] >= 5000, 'Employee_Count_Total_buckets'] =3


cols_for_pred = ['DUNS','Domestic_Ult_Emp_Range_num', 'Domestic_Ult_Revenue_Range_num','Employee_Count_Range_num','Employee_Count_Total_buckets2', 'Minority_Owned_Indicator_num','Population_Code_recoded', 'Revenue_Range_buckets', 'Revenue_per_emp_LMH','company_age_group','Employee_Count_Total_buckets','Manufacturing_Indicator','Major_Industry_Category']




df_pred = df_pred[cols_for_pred]



df_pred["seg1_prior"] = 0.1560*10**9 
df_pred["seg2_prior"] = 0.1322*10**9 
df_pred["seg3_prior"] = 0.1583*10**9 
df_pred["seg4_prior"] = 0.2029*10**9 
df_pred["seg5_prior"] = 0.1706*10**9 
df_pred["seg6_prior"] = 0.1799*10**9 



#Domestic_Ult_Revenue_Range_num

df_pred["Seg1_Dom_rev_range_prob"] = np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 1,0.0197,
             np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 2, 0.00985, 
                   np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 3, 0,
                            np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 4, 0,
                                     np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 5, 0.01478,
                                              np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 6, 0.00985,
                                                       np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 7, 0.03448,
                                                                np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 8, 0.04926,
                                                                         np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 9, 0.02956,
                                                                                  np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 10, 0.83251, 1))))))))))


df_pred["Seg2_Dom_rev_range_prob"] = np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 1,0.62209,
             np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 2, 0.05814, 
                   np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 3, 0.02907,
                            np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 4, 0.02907,
                                     np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 5, 0.01163,
                                              np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 6, 0.00581,
                                                       np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 7, 0.02907,
                                                                np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 8, 0.01163,
                                                                         np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 9, 0.00581,
                                                                                  np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 10, 0.19767, 1))))))))))

df_pred["Seg3_Dom_rev_range_prob"] = np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 1,0.04369,
             np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 2, 0.00485, 
                   np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 3, 0.00485,
                            np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 4, 0,
                                     np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 5, 0,
                                              np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 6, 0,
                                                       np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 7, 0.0534,
                                                                np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 8, 0.06796,
                                                                         np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 9, 0.10194,
                                                                                  np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 10, 0.7233, 1))))))))))

df_pred["Seg4_Dom_rev_range_prob"] = np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 1,0.04545,
             np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 2, 0.12879, 
                   np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 3, 0.10985,
                            np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 4, 0.19697,
                                     np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 5, 0.11364,
                                              np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 6, 0.11742,
                                                       np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 7, 0.12879,
                                                                np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 8, 0.07197,
                                                                         np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 9, 0.03409,
                                                                                  np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 10, 0.05303, 1))))))))))

df_pred["Seg5_Dom_rev_range_prob"] = np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 1,0.73423,
             np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 2, 0.14865, 
                   np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 3, 0.02252,
                            np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 4, 0.00901,
                                     np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 5, 0.01351,
                                              np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 6, 0.0045,
                                                       np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 7, 0,
                                                                np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 8, 0.0045,
                                                                         np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 9, 0.00901,
                                                                                  np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 10, 0.05405, 1))))))))))

df_pred["Seg6_Dom_rev_range_prob"] = np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 1,0.6453,
             np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 2, 0.10684, 
                   np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 3, 0.01282,
                            np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 4, 0.02137,
                                     np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 5, 0.00855,
                                              np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 6, 0.01709,
                                                       np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 7, 0.00855,
                                                                np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 8, 0.01282,
                                                                         np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 9, 0.01282,
                                                                                  np.where(df_pred['Domestic_Ult_Revenue_Range_num']== 10, 0.15385, 1))))))))))


#Employee_Count_Range_num

df_pred["Seg1_Emp_count_range_prob"] = np.where(df_pred['Employee_Count_Range_num']== 1,0.23153,
             np.where(df_pred['Employee_Count_Range_num']== 2, 0.10345, 
                   np.where(df_pred['Employee_Count_Range_num']== 3, 0.27094,
                            np.where(df_pred['Employee_Count_Range_num']== 4, 0.10345,
                                     np.where(df_pred['Employee_Count_Range_num']== 5, 0.21675,
                                              np.where(df_pred['Employee_Count_Range_num']== 6, 0.05911,
                                                       np.where(df_pred['Employee_Count_Range_num']== 7, 0.01478, 1 )))))))

df_pred["Seg2_Emp_count_range_prob"] = np.where(df_pred['Employee_Count_Range_num']== 1,0.86628,
             np.where(df_pred['Employee_Count_Range_num']== 2, 0.06977, 
                   np.where(df_pred['Employee_Count_Range_num']== 3, 0.04651,
                            np.where(df_pred['Employee_Count_Range_num']== 4, 0.01163,
                                     np.where(df_pred['Employee_Count_Range_num']== 5, 0.00581,
                                              np.where(df_pred['Employee_Count_Range_num']== 6, 0,
                                                       np.where(df_pred['Employee_Count_Range_num']== 7, 0, 1 )))))))

df_pred["Seg3_Emp_count_range_prob"] = np.where(df_pred['Employee_Count_Range_num']== 1,0.11165,
             np.where(df_pred['Employee_Count_Range_num']== 2, 0.12621, 
                   np.where(df_pred['Employee_Count_Range_num']== 3, 0.36408,
                            np.where(df_pred['Employee_Count_Range_num']== 4, 0.1165,
                                     np.where(df_pred['Employee_Count_Range_num']== 5, 0.20388,
                                              np.where(df_pred['Employee_Count_Range_num']== 6, 0.07282,
                                                       np.where(df_pred['Employee_Count_Range_num']== 7, 0.00485, 1 )))))))


df_pred["Seg4_Emp_count_range_prob"] = np.where(df_pred['Employee_Count_Range_num']== 1,0.14394,
             np.where(df_pred['Employee_Count_Range_num']== 2, 0.5, 
                   np.where(df_pred['Employee_Count_Range_num']== 3, 0.31818,
                            np.where(df_pred['Employee_Count_Range_num']== 4, 0.03788,
                                     np.where(df_pred['Employee_Count_Range_num']== 5, 0,
                                              np.where(df_pred['Employee_Count_Range_num']== 6, 0,
                                                       np.where(df_pred['Employee_Count_Range_num']== 7, 0, 1 )))))))

df_pred["Seg5_Emp_count_range_prob"] = np.where(df_pred['Employee_Count_Range_num']== 1,0.95495,
             np.where(df_pred['Employee_Count_Range_num']== 2, 0.01351, 
                   np.where(df_pred['Employee_Count_Range_num']== 3, 0.02252,
                            np.where(df_pred['Employee_Count_Range_num']== 4, 0.00901,
                                     np.where(df_pred['Employee_Count_Range_num']== 5, 0,
                                              np.where(df_pred['Employee_Count_Range_num']== 6, 0,
                                                       np.where(df_pred['Employee_Count_Range_num']== 7, 0, 1 )))))))

df_pred["Seg6_Emp_count_range_prob"] = np.where(df_pred['Employee_Count_Range_num']== 1,0.87607,
             np.where(df_pred['Employee_Count_Range_num']== 2, 0.04274, 
                   np.where(df_pred['Employee_Count_Range_num']== 3, 0.07265,
                            np.where(df_pred['Employee_Count_Range_num']== 4, 0.00427,
                                     np.where(df_pred['Employee_Count_Range_num']== 5, 0.00427,
                                              np.where(df_pred['Employee_Count_Range_num']== 6, 0,
                                                       np.where(df_pred['Employee_Count_Range_num']== 7, 0, 1 )))))))

#Employee_Count_Total_buckets2

df_pred["Seg1_Emp_count_buckets2_prob"] = np.where(df_pred['Employee_Count_Total_buckets2']== 1,0.12808,
             np.where(df_pred['Employee_Count_Total_buckets2']== 2, 0.0197, 
                   np.where(df_pred['Employee_Count_Total_buckets2']== 3, 0.85222, 1)))

df_pred["Seg2_Emp_count_buckets2_prob"] = np.where(df_pred['Employee_Count_Total_buckets2']== 1,0.99419,
             np.where(df_pred['Employee_Count_Total_buckets2']== 2, 0.00581, 
                   np.where(df_pred['Employee_Count_Total_buckets2']== 3, 0, 1)))

df_pred["Seg3_Emp_count_buckets2_prob"] = np.where(df_pred['Employee_Count_Total_buckets2']== 1,0.09223,
             np.where(df_pred['Employee_Count_Total_buckets2']== 2, 0.1165, 
                   np.where(df_pred['Employee_Count_Total_buckets2']== 3, 0.79126, 1)))

df_pred["Seg4_Emp_count_buckets2_prob"] = np.where(df_pred['Employee_Count_Total_buckets2']== 1,0.01515,
             np.where(df_pred['Employee_Count_Total_buckets2']== 2, 0.98485, 
                   np.where(df_pred['Employee_Count_Total_buckets2']== 3, 0, 1)))

df_pred["Seg5_Emp_count_buckets2_prob"] = np.where(df_pred['Employee_Count_Total_buckets2']== 1,0.98649,
             np.where(df_pred['Employee_Count_Total_buckets2']== 2, 0.01351, 
                   np.where(df_pred['Employee_Count_Total_buckets2']== 3, 0, 1)))
                            
df_pred["Seg6_Emp_count_buckets2_prob"] = np.where(df_pred['Employee_Count_Total_buckets2']== 1,0.98718,
             np.where(df_pred['Employee_Count_Total_buckets2']== 2, 0.01282, 
                   np.where(df_pred['Employee_Count_Total_buckets2']== 3, 0, 1)))

#Major_Industry_Category

df_pred["Seg1_industry_cat_prob"] = np.where(df_pred['Major_Industry_Category']== 0, 0.00985,
             np.where(df_pred['Major_Industry_Category']== 1, 0, 
                   np.where(df_pred['Major_Industry_Category']== 2, 0,
                            np.where(df_pred['Major_Industry_Category']== 3, 0,
                                     np.where(df_pred['Major_Industry_Category']== 4, 0.24138,
                                              np.where(df_pred['Major_Industry_Category']== 5, 0.05911,
                                                       np.where(df_pred['Major_Industry_Category']== 6, 0.03941,
                                                                np.where(df_pred['Major_Industry_Category']== 7, 0.14778,
                                                                         np.where(df_pred['Major_Industry_Category']== 8, 0.15764,
                                                                                  np.where(df_pred['Major_Industry_Category']== 9, 0.34483, 1))))))))))

df_pred["Seg2_industry_cat_prob"] = np.where(df_pred['Major_Industry_Category']== 0, 0.13953,
             np.where(df_pred['Major_Industry_Category']== 1, 0, 
                   np.where(df_pred['Major_Industry_Category']== 2, 0.00581,
                            np.where(df_pred['Major_Industry_Category']== 3, 0.01744,
                                     np.where(df_pred['Major_Industry_Category']== 4, 0.06977,
                                              np.where(df_pred['Major_Industry_Category']== 5, 0.06977,
                                                       np.where(df_pred['Major_Industry_Category']== 6, 0.05814,
                                                                np.where(df_pred['Major_Industry_Category']== 7, 0.09884,
                                                                         np.where(df_pred['Major_Industry_Category']== 8, 0.07558,
                                                                                  np.where(df_pred['Major_Industry_Category']== 9, 0.46512, 1))))))))))

df_pred["Seg3_industry_cat_prob"] = np.where(df_pred['Major_Industry_Category']== 0, 0.02427,
             np.where(df_pred['Major_Industry_Category']== 1, 0, 
                   np.where(df_pred['Major_Industry_Category']== 2, 0,
                            np.where(df_pred['Major_Industry_Category']== 3, 0,
                                     np.where(df_pred['Major_Industry_Category']== 4, 0.21845,
                                              np.where(df_pred['Major_Industry_Category']== 5, 0.07282,
                                                       np.where(df_pred['Major_Industry_Category']== 6, 0.01456,
                                                                np.where(df_pred['Major_Industry_Category']== 7, 0.07767,
                                                                         np.where(df_pred['Major_Industry_Category']== 8, 0.15049,
                                                                                  np.where(df_pred['Major_Industry_Category']== 9, 0.44175, 1))))))))))

df_pred["Seg4_industry_cat_prob"] = np.where(df_pred['Major_Industry_Category']== 0, 0.00758,
             np.where(df_pred['Major_Industry_Category']== 1, 0.01515, 
                   np.where(df_pred['Major_Industry_Category']== 2, 0,
                            np.where(df_pred['Major_Industry_Category']== 3, 0.04924,
                                     np.where(df_pred['Major_Industry_Category']== 4, 0.23106,
                                              np.where(df_pred['Major_Industry_Category']== 5, 0.05682,
                                                       np.where(df_pred['Major_Industry_Category']== 6, 0.10227,
                                                                np.where(df_pred['Major_Industry_Category']== 7, 0.06439,
                                                                         np.where(df_pred['Major_Industry_Category']== 8, 0.10227,
                                                                                  np.where(df_pred['Major_Industry_Category']== 9, 0.37121, 1))))))))))

df_pred["Seg5_industry_cat_prob"] = np.where(df_pred['Major_Industry_Category']== 0, 0.11261,
             np.where(df_pred['Major_Industry_Category']== 1, 0.00901, 
                   np.where(df_pred['Major_Industry_Category']== 2, 0,
                            np.where(df_pred['Major_Industry_Category']== 3, 0.07658,
                                     np.where(df_pred['Major_Industry_Category']== 4, 0.06757,
                                              np.where(df_pred['Major_Industry_Category']== 5, 0.05856,
                                                       np.where(df_pred['Major_Industry_Category']== 6, 0.10811,
                                                                np.where(df_pred['Major_Industry_Category']== 7, 0.11712,
                                                                         np.where(df_pred['Major_Industry_Category']== 8, 0.0991,
                                                                                  np.where(df_pred['Major_Industry_Category']== 9, 0.35135, 1))))))))))

df_pred["Seg6_industry_cat_prob"] = np.where(df_pred['Major_Industry_Category']== 0, 0.1453,
             np.where(df_pred['Major_Industry_Category']== 1, 0.00427, 
                   np.where(df_pred['Major_Industry_Category']== 2, 0,
                            np.where(df_pred['Major_Industry_Category']== 3, 0.02137,
                                     np.where(df_pred['Major_Industry_Category']== 4, 0.0812,
                                              np.where(df_pred['Major_Industry_Category']== 5, 0.04701,
                                                       np.where(df_pred['Major_Industry_Category']== 6, 0.04701,
                                                                np.where(df_pred['Major_Industry_Category']== 7, 0.17521,
                                                                         np.where(df_pred['Major_Industry_Category']== 8, 0.10684,
                                                                                  np.where(df_pred['Major_Industry_Category']== 9, 0.37179, 1))))))))))




#Minority_Owned_Indicator_num


df_pred["Seg1_minority_ind_prob"] = np.where(df_pred['Minority_Owned_Indicator_num']== 0, 0.98387,
             np.where(df_pred['Minority_Owned_Indicator_num']== 1, 0.01613, 1 ))

df_pred["Seg2_minority_ind_prob"] = np.where(df_pred['Minority_Owned_Indicator_num']== 0, 0.94083,
             np.where(df_pred['Minority_Owned_Indicator_num']== 1, 0.05917, 1 ))

df_pred["Seg3_minority_ind_prob"] = np.where(df_pred['Minority_Owned_Indicator_num']== 0, 1,
             np.where(df_pred['Minority_Owned_Indicator_num']== 1, 0, 1 ))

df_pred["Seg4_minority_ind_prob"] = np.where(df_pred['Minority_Owned_Indicator_num']== 0, 0.96234,
             np.where(df_pred['Minority_Owned_Indicator_num']== 1, 0.03766, 1 ))

df_pred["Seg5_minority_ind_prob"] = np.where(df_pred['Minority_Owned_Indicator_num']== 0, 0.99492,
             np.where(df_pred['Minority_Owned_Indicator_num']== 1, 0.00508, 1 ))

df_pred["Seg6_minority_ind_prob"] = np.where(df_pred['Minority_Owned_Indicator_num']== 0, 0.99074,
             np.where(df_pred['Minority_Owned_Indicator_num']== 1, 0.00926, 1 ))



#Population_Code_recoded

df_pred["Seg1_pop_code_prob"] = np.where(df_pred['Population_Code_recoded']== 1, 0.08374,
             np.where(df_pred['Population_Code_recoded']== 2, 0, 
                   np.where(df_pred['Population_Code_recoded']== 3, 0,
                            np.where(df_pred['Population_Code_recoded']== 4, 0.01478,
                                     np.where(df_pred['Population_Code_recoded']== 5, 0.06404,
                                              np.where(df_pred['Population_Code_recoded']== 6, 0.05419,
                                                       np.where(df_pred['Population_Code_recoded']== 7, 0.78325, 1 )))))))
                                                                         
df_pred["Seg2_pop_code_prob"] = np.where(df_pred['Population_Code_recoded']== 1, 0.01744,
             np.where(df_pred['Population_Code_recoded']== 2, 0.01163, 
                   np.where(df_pred['Population_Code_recoded']== 3, 0.04651,
                            np.where(df_pred['Population_Code_recoded']== 4, 0.01744,
                                     np.where(df_pred['Population_Code_recoded']== 5, 0.05233,
                                              np.where(df_pred['Population_Code_recoded']== 6, 0.24419,
                                                       np.where(df_pred['Population_Code_recoded']== 7, 0.61047, 1 )))))))


df_pred["Seg3_pop_code_prob"] = np.where(df_pred['Population_Code_recoded']== 1, 0,
             np.where(df_pred['Population_Code_recoded']== 2, 0.00971, 
                   np.where(df_pred['Population_Code_recoded']== 3, 0.01942,
                            np.where(df_pred['Population_Code_recoded']== 4, 0.02427,
                                     np.where(df_pred['Population_Code_recoded']== 5, 0.15049,
                                              np.where(df_pred['Population_Code_recoded']== 6, 0.08252,
                                                       np.where(df_pred['Population_Code_recoded']== 7, 0.71359, 1 )))))))


df_pred["Seg4_pop_code_prob"] = np.where(df_pred['Population_Code_recoded']== 1, 0.0947,
             np.where(df_pred['Population_Code_recoded']== 2, 0.03409, 
                   np.where(df_pred['Population_Code_recoded']== 3, 0.0303,
                            np.where(df_pred['Population_Code_recoded']== 4, 0.07576,
                                     np.where(df_pred['Population_Code_recoded']== 5, 0.07197,
                                              np.where(df_pred['Population_Code_recoded']== 6, 0.14015,
                                                       np.where(df_pred['Population_Code_recoded']== 7, 0.55303, 1 )))))))


df_pred["Seg5_pop_code_prob"] = np.where(df_pred['Population_Code_recoded']== 1, 0.11261,
             np.where(df_pred['Population_Code_recoded']== 2, 0.00901, 
                   np.where(df_pred['Population_Code_recoded']== 3, 0.00901,
                            np.where(df_pred['Population_Code_recoded']== 4, 0.07658,
                                     np.where(df_pred['Population_Code_recoded']== 5, 0.0991,
                                              np.where(df_pred['Population_Code_recoded']== 6, 0.13964,
                                                       np.where(df_pred['Population_Code_recoded']== 7, 0.55405, 1 )))))))


df_pred["Seg6_pop_code_prob"] = np.where(df_pred['Population_Code_recoded']== 1, 0.07692,
             np.where(df_pred['Population_Code_recoded']== 2, 0, 
                   np.where(df_pred['Population_Code_recoded']== 3, 0.05983,
                            np.where(df_pred['Population_Code_recoded']== 4, 0.02991,
                                     np.where(df_pred['Population_Code_recoded']== 5, 0.11538,
                                              np.where(df_pred['Population_Code_recoded']== 6, 0.07692,
                                                       np.where(df_pred['Population_Code_recoded']== 7, 0.64103, 1 )))))))

#Revenue_Range_buckets


df_pred["Seg1_rev_range_buckets_prob"] = np.where(df_pred['Revenue_Range_buckets']== 1, 0.13793,
             np.where(df_pred['Revenue_Range_buckets']== 2, 0.2069, 
                   np.where(df_pred['Revenue_Range_buckets']== 3, 0.65517, 1)))

df_pred["Seg2_rev_range_buckets_prob"] = np.where(df_pred['Revenue_Range_buckets']== 1, 0.95349,
             np.where(df_pred['Revenue_Range_buckets']== 2, 0.04651, 
                   np.where(df_pred['Revenue_Range_buckets']== 3, 0, 1)))

df_pred["Seg3_rev_range_buckets_prob"] = np.where(df_pred['Revenue_Range_buckets']== 1, 0.12621,
             np.where(df_pred['Revenue_Range_buckets']== 2, 0.35922, 
                   np.where(df_pred['Revenue_Range_buckets']== 3, 0.51456, 1)))

df_pred["Seg4_rev_range_buckets_prob"] = np.where(df_pred['Revenue_Range_buckets']== 1, 0.19318,
             np.where(df_pred['Revenue_Range_buckets']== 2, 0.79545, 
                   np.where(df_pred['Revenue_Range_buckets']== 3, 0.01136, 1)))

df_pred["Seg5_rev_range_buckets_prob"] = np.where(df_pred['Revenue_Range_buckets']== 1, 0.95045,
             np.where(df_pred['Revenue_Range_buckets']== 2, 0.04505, 
                   np.where(df_pred['Revenue_Range_buckets']== 3, 0.0045, 1)))

df_pred["Seg6_rev_range_buckets_prob"] = np.where(df_pred['Revenue_Range_buckets']== 1, 0.97009,
             np.where(df_pred['Revenue_Range_buckets']== 2, 0.02564, 
                   np.where(df_pred['Revenue_Range_buckets']== 3, 0.00427, 1)))


#Revenue_per_emp_LMH

df_pred["Seg1_rev_per_emp_LMH_prob"] = np.where(df_pred['Revenue_per_emp_LMH']== 1, 0.11299,
             np.where(df_pred['Revenue_per_emp_LMH']== 2, 0.32203, 
                   np.where(df_pred['Revenue_per_emp_LMH']== 3, 0.56497, 1)))


df_pred["Seg2_rev_per_emp_LMH_prob"] = np.where(df_pred['Revenue_per_emp_LMH']== 1, 0.59048,
             np.where(df_pred['Revenue_per_emp_LMH']== 2, 0.28571, 
                   np.where(df_pred['Revenue_per_emp_LMH']== 3, 0.12381, 1)))

df_pred["Seg3_rev_per_emp_LMH_prob"] = np.where(df_pred['Revenue_per_emp_LMH']== 1, 0.1087,
             np.where(df_pred['Revenue_per_emp_LMH']== 2, 0.43478, 
                   np.where(df_pred['Revenue_per_emp_LMH']== 3, 0.45652, 1)))

df_pred["Seg4_rev_per_emp_LMH_prob"] = np.where(df_pred['Revenue_per_emp_LMH']== 1, 0.12791,
             np.where(df_pred['Revenue_per_emp_LMH']== 2, 0.53488, 
                   np.where(df_pred['Revenue_per_emp_LMH']== 3, 0.33721, 1)))

df_pred["Seg5_rev_per_emp_LMH_prob"] = np.where(df_pred['Revenue_per_emp_LMH']== 1, 0.55249,
             np.where(df_pred['Revenue_per_emp_LMH']== 2, 0.34807, 
                   np.where(df_pred['Revenue_per_emp_LMH']== 3, 0.09945, 1)))

df_pred["Seg6_rev_per_emp_LMH_prob"] = np.where(df_pred['Revenue_per_emp_LMH']== 1, 0.55975,
             np.where(df_pred['Revenue_per_emp_LMH']== 2, 0.34591, 
                   np.where(df_pred['Revenue_per_emp_LMH']== 3, 0.09434, 1)))


#company_age_group


df_pred["Seg1_age_group_prob"] = np.where(df_pred['company_age_group']== 1, 0.04469,
             np.where(df_pred['company_age_group']== 2, 0.10615, 
                   np.where(df_pred['company_age_group']== 3, 0.26816,
                            np.where(df_pred['company_age_group']== 4, 0.29609,
                                     np.where(df_pred['company_age_group']== 5, 0.28492, 1)))))


df_pred["Seg2_age_group_prob"] = np.where(df_pred['company_age_group']== 1, 0.23148,
             np.where(df_pred['company_age_group']== 2, 0.43519, 
                   np.where(df_pred['company_age_group']== 3, 0.24074,
                            np.where(df_pred['company_age_group']== 4, 0.05556,
                                     np.where(df_pred['company_age_group']== 5, 0.03704, 1)))))

df_pred["Seg3_age_group_prob"] = np.where(df_pred['company_age_group']== 1, 0.05851,
             np.where(df_pred['company_age_group']== 2, 0.1117, 
                   np.where(df_pred['company_age_group']== 3, 0.19149,
                            np.where(df_pred['company_age_group']== 4, 0.22872,
                                     np.where(df_pred['company_age_group']== 5, 0.40957, 1)))))

df_pred["Seg4_age_group_prob"] = np.where(df_pred['company_age_group']== 1, 0.03937,
             np.where(df_pred['company_age_group']== 2, 0.12992, 
                   np.where(df_pred['company_age_group']== 3, 0.33071,
                            np.where(df_pred['company_age_group']== 4, 0.3189,
                                     np.where(df_pred['company_age_group']== 5, 0.1811, 1)))))

df_pred["Seg5_age_group_prob"] = np.where(df_pred['company_age_group']== 1, 0.1676,
             np.where(df_pred['company_age_group']== 2, 0.40223, 
                   np.where(df_pred['company_age_group']== 3, 0.28492,
                            np.where(df_pred['company_age_group']== 4, 0.11173,
                                     np.where(df_pred['company_age_group']== 5, 0.03352, 1)))))

df_pred["Seg6_age_group_prob"] = np.where(df_pred['company_age_group']== 1, 0.19876,
             np.where(df_pred['company_age_group']== 2, 0.43478, 
                   np.where(df_pred['company_age_group']== 3, 0.26087,
                            np.where(df_pred['company_age_group']== 4, 0.08696,
                                     np.where(df_pred['company_age_group']== 5, 0.01863, 1)))))


#Employee_Count_Total_buckets

df_pred["Seg1_emp_count_buckets_prob"] = np.where(df_pred['Employee_Count_Total_buckets']== 1, 0.14778,
             np.where(df_pred['Employee_Count_Total_buckets']== 2, 0.23645, 
                   np.where(df_pred['Employee_Count_Total_buckets']== 3, 0.61576, 1)))

df_pred["Seg2_emp_count_buckets_prob"] = np.where(df_pred['Employee_Count_Total_buckets']== 1, 1,
             np.where(df_pred['Employee_Count_Total_buckets']== 2, 0, 
                   np.where(df_pred['Employee_Count_Total_buckets']== 3, 0, 1)))

df_pred["Seg3_emp_count_buckets_prob"] = np.where(df_pred['Employee_Count_Total_buckets']== 1, 0.20388,
             np.where(df_pred['Employee_Count_Total_buckets']== 2, 0.25243, 
                   np.where(df_pred['Employee_Count_Total_buckets']== 3, 0.54369, 1)))

df_pred["Seg4_emp_count_buckets_prob"] = np.where(df_pred['Employee_Count_Total_buckets']== 1, 0.98485,
             np.where(df_pred['Employee_Count_Total_buckets']== 2, 0.01515, 
                   np.where(df_pred['Employee_Count_Total_buckets']== 3, 0, 1)))

df_pred["Seg5_emp_count_buckets_prob"] = np.where(df_pred['Employee_Count_Total_buckets']== 1, 1,
             np.where(df_pred['Employee_Count_Total_buckets']== 2, 0, 
                   np.where(df_pred['Employee_Count_Total_buckets']== 3, 0, 1)))

df_pred["Seg6_emp_count_buckets_prob"] = np.where(df_pred['Employee_Count_Total_buckets']== 1, 1,
             np.where(df_pred['Employee_Count_Total_buckets']== 2, 0, 
                   np.where(df_pred['Employee_Count_Total_buckets']== 3, 0, 1)))



#Manufacturing_Indicator

df_pred["Seg1_manufacturing_ind_prob"] = np.where(df_pred['Manufacturing_Indicator']== 0, 0.36453,
             np.where(df_pred['Manufacturing_Indicator']== 1, 0.63547, 1))

df_pred["Seg2_manufacturing_ind_prob"] = np.where(df_pred['Manufacturing_Indicator']== 0, 0.08721,
             np.where(df_pred['Manufacturing_Indicator']== 1, 0.91279, 1))

df_pred["Seg3_manufacturing_ind_prob"] = np.where(df_pred['Manufacturing_Indicator']== 0, 0.24272,
             np.where(df_pred['Manufacturing_Indicator']== 1, 0.75728, 1))

df_pred["Seg4_manufacturing_ind_prob"] = np.where(df_pred['Manufacturing_Indicator']== 0, 0.30682,
             np.where(df_pred['Manufacturing_Indicator']== 1, 0.69318, 1))

df_pred["Seg5_manufacturing_ind_prob"] = np.where(df_pred['Manufacturing_Indicator']== 0, 0.18018,
             np.where(df_pred['Manufacturing_Indicator']== 1, 0.81982, 1))

df_pred["Seg6_manufacturing_ind_prob"] = np.where(df_pred['Manufacturing_Indicator']== 0, 0.15385,
             np.where(df_pred['Manufacturing_Indicator']== 1, 0.84615, 1))


df_pred_check = df_pred.iloc[:100]

df_pred["seg1_prob"] = df_pred.seg1_prior * df_pred.Seg1_Dom_rev_range_prob * df_pred.Seg1_Emp_count_range_prob * df_pred.Seg1_Emp_count_buckets2_prob * df_pred.Seg1_industry_cat_prob * df_pred.Seg1_minority_ind_prob * df_pred.Seg1_pop_code_prob * df_pred.Seg1_rev_range_buckets_prob * df_pred.Seg1_rev_per_emp_LMH_prob * df_pred.Seg1_age_group_prob * df_pred.Seg1_emp_count_buckets_prob * df_pred.Seg1_manufacturing_ind_prob
df_pred["seg2_prob"] = df_pred.seg2_prior * df_pred.Seg2_Dom_rev_range_prob * df_pred.Seg2_Emp_count_range_prob * df_pred.Seg2_Emp_count_buckets2_prob * df_pred.Seg2_industry_cat_prob * df_pred.Seg2_minority_ind_prob * df_pred.Seg2_pop_code_prob * df_pred.Seg2_rev_range_buckets_prob * df_pred.Seg2_rev_per_emp_LMH_prob * df_pred.Seg2_age_group_prob * df_pred.Seg2_emp_count_buckets_prob * df_pred.Seg2_manufacturing_ind_prob
df_pred["seg3_prob"] = df_pred.seg3_prior * df_pred.Seg3_Dom_rev_range_prob * df_pred.Seg3_Emp_count_range_prob * df_pred.Seg3_Emp_count_buckets2_prob * df_pred.Seg3_industry_cat_prob * df_pred.Seg3_minority_ind_prob * df_pred.Seg3_pop_code_prob * df_pred.Seg3_rev_range_buckets_prob * df_pred.Seg3_rev_per_emp_LMH_prob * df_pred.Seg3_age_group_prob * df_pred.Seg3_emp_count_buckets_prob * df_pred.Seg3_manufacturing_ind_prob
df_pred["seg4_prob"] = df_pred.seg4_prior * df_pred.Seg4_Dom_rev_range_prob * df_pred.Seg4_Emp_count_range_prob * df_pred.Seg4_Emp_count_buckets2_prob * df_pred.Seg4_industry_cat_prob * df_pred.Seg4_minority_ind_prob * df_pred.Seg4_pop_code_prob * df_pred.Seg4_rev_range_buckets_prob * df_pred.Seg4_rev_per_emp_LMH_prob * df_pred.Seg4_age_group_prob * df_pred.Seg4_emp_count_buckets_prob * df_pred.Seg4_manufacturing_ind_prob
df_pred["seg5_prob"] = df_pred.seg5_prior * df_pred.Seg5_Dom_rev_range_prob * df_pred.Seg5_Emp_count_range_prob * df_pred.Seg5_Emp_count_buckets2_prob * df_pred.Seg5_industry_cat_prob * df_pred.Seg5_minority_ind_prob * df_pred.Seg5_pop_code_prob * df_pred.Seg5_rev_range_buckets_prob * df_pred.Seg5_rev_per_emp_LMH_prob * df_pred.Seg5_age_group_prob * df_pred.Seg5_emp_count_buckets_prob * df_pred.Seg5_manufacturing_ind_prob
df_pred["seg6_prob"] = df_pred.seg6_prior * df_pred.Seg6_Dom_rev_range_prob * df_pred.Seg6_Emp_count_range_prob * df_pred.Seg6_Emp_count_buckets2_prob * df_pred.Seg6_industry_cat_prob * df_pred.Seg6_minority_ind_prob * df_pred.Seg6_pop_code_prob * df_pred.Seg6_rev_range_buckets_prob * df_pred.Seg6_rev_per_emp_LMH_prob * df_pred.Seg6_age_group_prob * df_pred.Seg6_emp_count_buckets_prob * df_pred.Seg6_manufacturing_ind_prob


df_pred["sum_prob"]    = df_pred.seg1_prob + df_pred.seg2_prob + df_pred.seg3_prob + df_pred.seg4_prob + df_pred.seg5_prob + df_pred.seg6_prob 
df_pred["seg1_final_prob"] = round(df_pred.seg1_prob/df_pred.sum_prob,3)
df_pred["seg2_final_prob"] = round(df_pred.seg2_prob/df_pred.sum_prob,3)
df_pred["seg3_final_prob"] = round(df_pred.seg3_prob/df_pred.sum_prob,3)
df_pred["seg4_final_prob"] = round(df_pred.seg4_prob/df_pred.sum_prob,3)
df_pred["seg5_final_prob"] = round(df_pred.seg5_prob/df_pred.sum_prob,3)
df_pred["seg6_final_prob"] = round(df_pred.seg6_prob/df_pred.sum_prob,3)
df_pred["pred_probability"] = df_pred[['seg1_final_prob', 'seg2_final_prob', 'seg3_final_prob', 'seg4_final_prob', 'seg5_final_prob', 'seg6_final_prob']].max(axis=1 )


df_pred.loc[(df_pred["pred_probability"] == df_pred["seg3_final_prob"]),"pred_segment_final"] = 'Non Target Segment'
df_pred.loc[(df_pred["pred_probability"] == df_pred["seg4_final_prob"]),"pred_segment_final"] = 'Non Target Segment'
df_pred.loc[(df_pred["pred_probability"] == df_pred["seg6_final_prob"]),"pred_segment_final"] = 'Non Target Segment'
df_pred.loc[(df_pred["pred_probability"] == df_pred["seg5_final_prob"]),"pred_segment_final"] = 'Segment C'
df_pred.loc[(df_pred["pred_probability"] == df_pred["seg1_final_prob"]),"pred_segment_final"] = 'Segment B'
df_pred.loc[(df_pred["pred_probability"] == df_pred["seg2_final_prob"]),"pred_segment_final"] = 'Segment A'




df_publish = df_pred[['DUNS','pred_probability', 'pred_segment_final', 'seg1_final_prob', 'seg2_final_prob','seg3_final_prob', 'seg4_final_prob', 'seg5_final_prob' , 'seg6_final_prob']]

df_pred_size_check = df_publish.groupby('pred_segment_final')[['DUNS']].count()


df_publish.to_csv("Output_tags_cd_equals_9_sample.csv")
